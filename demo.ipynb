# %% [markdown]
# Notes
#
#  - Why is Pandas good, why are data frames good
#  - Benefits of easily manipulating records with Pandas
#  - easy to save out to multiple different file formats for archive with pandas
#  - However, while pandas is good for manipuating records, it isn't a database so can't handle issues sorroundinc creating multiple records.

# %% [markdown]
# # Sumatra and Pandas in IPython
#
# This notebook demonstrates using Sumatra to record simulations for a toy problem and then export the Sumatra records to a Pandas Dataframe.
#
#  * Sumatra is a simulation management tool.
#
#  * Pandas is a data analysis library.
#
# Let's start by creating a toy problem. The problem is to time FiPy simulations for different sized domains for different numbers of nodes.

# %%
import json

params = {'N' : 10, 'suite' : 'trilinos', 'iterations' : 100}

with open('params.json', 'wb') as fp:
    json.dump(params, fp)

# %%
# %%writefile fipy_timing.py

import json
import timeit
import numpy as np
import fipy as fp

with open('params.json', 'rb') as ff:
    params = json.load(ff)
    
N = params['N']
iterations = params['iterations']
suite = params['suite']

attempts = 3

setup_str = '''
import fipy as fp
import numpy as np
np.random.seed(1)
L = 1.
N = {N:d}
m = fp.GmshGrid3D(nx=N, ny=N, nz=N, dx=L / N, dy=L / N, dz=L / N)
v0 = np.random.random(m.numberOfCells)
v = fp.CellVariable(mesh=m)
v0 = np.resize(v0, len(v)) ## Gmsh doesn't always give us the correct sized grid!
eqn = fp.TransientTerm(1e-3) == fp.DiffusionTerm()
v[:] = v0.copy()

import fipy.solvers.{suite} as solvers
solver = solvers.linearPCGSolver.LinearPCGSolver(precon=None, iterations={iterations}, tolerance=1e-100)

eqn.solve(v, dt=1., solver=solver)
v[:] = v0.copy()
'''

timeit_str = '''
eqn.solve(v, dt=1., solver=solver)
fp.parallelComm.Barrier()
'''

timer = timeit.Timer(timeit_str, setup=setup_str.format(N=N, suite=suite, iterations=iterations))
times = timer.repeat(attempts, 1)

if fp.parallelComm.procID == 0:
    print min(times)
# Out:
# Overwriting fipy_timing.py

# %%
# !python fipy_timing.py
# Out:
# 0.0119581222534

# %% [markdown]
# In this demo, I'm assuming that the directory this notebook sits in is a Git repository set up with
#
#     $ git init
# $ git add fipy_timing.py
#     $ git ci -m "Add timing script."
#
# The first step is to create the a Sumatra repository with

# %%
 
    $ smt init smt_repository
    $ smt configure --executable=python --main=script.py
    $ smt configure --addlabel=cmdline
    $ smt configure --launch_mode=distributed
    $ smt configure -g uuid
    $ smt configure -c store-diff
    $ smt run -n 2 default.param
    $ smt info
# Out:
#   File "<ipython-input-14-5e32b4154b4a>", line 1
#     $ git init
#     ^
# SyntaxError: invalid syntax

# %%
import pandas$

df = pandas.DataFrame(data)

# %%
for depend in df['dependencies'][0]:
    if depend['name'] == 'fipy':
        print depend['version']
# Out:
# 6e897df400126ff8b935dd7344469f7c762c8553

# %%
print df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 0 to 1
# Data columns (total 23 columns):
# datastore           2  non-null values
# dependencies        2  non-null values
# diff                2  non-null values
# duration            2  non-null values
# executable          2  non-null values
# input_data          2  non-null values
# input_datastore     2  non-null values
# label               2  non-null values
# launch_mode         2  non-null values
# main_file           2  non-null values
# outcome             2  non-null values
# output_data         2  non-null values
# parameters          2  non-null values
# platforms           2  non-null values
# reason              2  non-null values
# repeats             0  non-null values
# repository          2  non-null values
# script_arguments    2  non-null values
# stdout_stderr       2  non-null values
# tags                2  non-null values
# timestamp           2  non-null values
# user                2  non-null values
# version             2  non-null values
# dtypes: float64(1), object(22)

# %%
import json
from pprint import pprint
json_data=open('.smt/records_export.json')

data = json.load(json_data)
pprint(data)
json_data.close()
# Out:
# [{u'datastore': {u'parameters': {u'root': u'/home/wd15/git/sumatrademo/Data/de3bd1d6f4f9'},
#                  u'type': u'FileSystemDataStore'},
#   u'dependencies': [{u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'Crypto',
#                      u'path': u'/usr/lib/python2.7/dist-packages/Crypto',
#                      u'source': u'attribute',
#                      u'version': u'2.6'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'IPython',
#                      u'path': u'/home/wd15/git/ipython/IPython',
#                      u'source': u'/home/wd15/git/ipython',
#                      u'version': u'b31eb2f2d95146bfc0873670c649378872492dc7'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'PIL',
#                      u'path': u'/usr/lib/python2.7/dist-packages/PIL',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'PyQt4',
#                      u'path': u'/usr/lib/python2.7/dist-packages/PyQt4',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'PySide',
#                      u'path': u'/usr/lib/python2.7/dist-packages/PySide',
#                      u'source': u'attribute',
#                      u'version': u'1.1.2'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'PyTrilinos',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/PyTrilinos',
#                      u'source': u'attribute',
#                      u'version': u'4.8d'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'_markerlib',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/distribute-0.6.34-py2.7.egg/_markerlib',
#                      u'source': u'egg-info',
#                      u'version': u'0.6.34'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'dateutil',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/dateutil',
#                      u'source': u'attribute',
#                      u'version': u'2.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'distutils',
#                      u'path': u'/home/wd15/.virtualenvs/default/lib/python2.7/distutils',
#                      u'source': u'attribute',
#                      u'version': u'2.7.5'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'docutils',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/docutils',
#                      u'source': u'attribute',
#                      u'version': u'0.11'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'encodings',
#                      u'path': u'/home/wd15/.virtualenvs/default/lib/python2.7/encodings',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'diff --git a/examples/cahnHilliard/mesh2D.py b/examples/cahnHilliard/mesh2D.py\nindex 73e98a6..35765ce 100755\n--- a/examples/cahnHilliard/mesh2D.py\n+++ b/examples/cahnHilliard/mesh2D.py\n@@ -67,7 +67,7 @@ We can simulate this process in :term:`FiPy` with a simple script:\n much is augmented for :term:`FiPy`\\\'s needs.)\n \n >>> if __name__ == "__main__":\n-...     nx = ny = 1000\n+...     nx = ny = 100\n ... else:\n ...     nx = ny = 20\n >>> mesh = Grid2D(nx=nx, ny=ny, dx=0.25, dy=0.25)\ndiff --git a/fipy/meshes/abstractMesh.py b/fipy/meshes/abstractMesh.py\nindex 46c8ed5..dba3bd4 100644\n--- a/fipy/meshes/abstractMesh.py\n+++ b/fipy/meshes/abstractMesh.py\n@@ -994,6 +994,7 @@ class AbstractMesh(object):\n     __div__ = __truediv__\n     \n     def __getstate__(self):\n+        print \'got here\'\n         return self.representation.getstate()\n \n     def __setstate__(self, state):',
#                      u'module': u'python',
#                      u'name': u'fipy',
#                      u'path': u'/home/wd15/git/fipy/fipy',
#                      u'source': u'/home/wd15/git/fipy',
#                      u'version': u'6e897df400126ff8b935dd7344469f7c762c8553'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'gi',
#                      u'path': u'/usr/lib/python2.7/dist-packages/gi',
#                      u'source': u'attribute',
#                      u'version': u'3.10.0'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'glib',
#                      u'path': u'/usr/lib/python2.7/dist-packages/glib',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'gobject',
#                      u'path': u'/usr/lib/python2.7/dist-packages/gobject',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'gtk',
#                      u'path': u'/usr/lib/python2.7/dist-packages/gtk-2.0/gtk',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'matplotlib',
#                      u'path': u'/usr/lib/pymodules/python2.7/matplotlib',
#                      u'source': u'attribute',
#                      u'version': u'1.2.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'mayavi',
#                      u'path': u'/usr/lib/python2.7/dist-packages/mayavi',
#                      u'source': u'attribute',
#                      u'version': u'4.1.0'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'mpi4py',
#                      u'path': u'/usr/lib/python2.7/dist-packages/mpi4py',
#                      u'source': u'attribute',
#                      u'version': u'1.3'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'mpl_toolkits',
#                      u'path': u'/usr/lib/pymodules/python2.7/mpl_toolkits',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'nose',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/nose',
#                      u'source': u'attribute',
#                      u'version': u'1.3.0'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'numpy',
#                      u'path': u'/usr/lib/python2.7/dist-packages/numpy',
#                      u'source': u'attribute',
#                      u'version': u'1.7.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'paramiko',
#                      u'path': u'/usr/lib/python2.7/dist-packages/paramiko',
#                      u'source': u'attribute',
#                      u'version': u'1.10.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'pylsmlib',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/pylsmlib-0.1-py2.7-linux-x86_64.egg/pylsmlib',
#                      u'source': u'attribute',
#                      u'version': u'0.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'pysparse',
#                      u'path': u'/home/wd15/git/pysparse/pysparse',
#                      u'source': u'/home/wd15/git/pysparse',
#                      u'version': u'1751931aa5c06429245c3aca3a3ba6d7622ea8b5'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'pytz',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/pytz',
#                      u'source': u'attribute',
#                      u'version': u'2013b'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'scipy',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/scipy',
#                      u'source': u'attribute',
#                      u'version': u'0.13.0'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'setuptools',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/distribute-0.6.34-py2.7.egg/setuptools',
#                      u'source': u'attribute',
#                      u'version': u'0.6'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'skfmm',
#                      u'path': u'/home/wd15/git/scikit-fmm/skfmm',
#                      u'source': u'/home/wd15/git/scikit-fmm',
#                      u'version': u'78a243dd9d8cf014e86bb859523226fa8ed65f10'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'tornado',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/tornado',
#                      u'source': u'attribute',
#                      u'version': u'3.1.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'traits',
#                      u'path': u'/usr/lib/python2.7/dist-packages/traits',
#                      u'source': u'attribute',
#                      u'version': u'4.1.0'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'tvtk',
#                      u'path': u'/usr/lib/python2.7/dist-packages/tvtk',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'vtk',
#                      u'path': u'/usr/lib/pymodules/python2.7/vtk',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'wx',
#                      u'path': u'/usr/lib/python2.7/dist-packages/wx-2.8-gtk2-unicode/wx',
#                      u'source': u'attribute',
#                      u'version': u'2.8.12.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'zmq',
#                      u'path': u'/usr/lib/python2.7/dist-packages/zmq',
#                      u'source': u'attribute',
#                      u'version': u'13.1.0'}],
#   u'diff': u'',
#   u'duration': 0.7446491718292236,
#   u'executable': {u'name': u'Python',
#                   u'options': u'',
#                   u'path': u'/home/wd15/.virtualenvs/default/bin/python',
#                   u'version': u'2.7.4'},
#   u'input_data': [],
#   u'input_datastore': {u'parameters': {u'root': u'/'},
#                        u'type': u'FileSystemDataStore'},
#   u'label': u'de3bd1d6f4f9',
#   u'launch_mode': {u'parameters': {u'options': None,
#                                    u'working_directory': u'/home/wd15/git/sumatrademo'},
#                    u'type': u'SerialLaunchMode'},
#   u'main_file': u'scripy.py',
#   u'outcome': u'',
#   u'output_data': [],
#   u'parameters': {u'content': u'{}', u'type': u'dict'},
#   u'platforms': [{u'architecture_bits': u'64bit',
#                   u'architecture_linkage': u'ELF',
#                   u'ip_addr': u'127.0.0.1',
#                   u'machine': u'x86_64',
#                   u'network_name': u'loki',
#                   u'processor': u'x86_64',
#                   u'release': u'3.11.0-13-generic',
#                   u'system_name': u'Linux',
#                   u'version': u'#20-Ubuntu SMP Wed Oct 23 07:38:26 UTC 2013'}],
#   u'reason': u'',
#   u'repeats': None,
#   u'repository': {u'type': u'GitRepository',
#                   u'upstream': None,
#                   u'url': u'/home/wd15/git/sumatrademo'},
#   u'script_arguments': u'',
#   u'stdout_stderr': u'No output.',
#   u'tags': [],
#   u'timestamp': u'2013-11-20 10:38:08',
#   u'user': u'Daniel Wheeler <daniel.wheeler2@gmail.com>',
#   u'version': u'90e58171d0489785d251cd7f1f0ae2a1e496438d'},
#  {u'datastore': {u'parameters': {u'root': u'/home/wd15/git/sumatrademo/Data/4880ebbcc856'},
#                  u'type': u'FileSystemDataStore'},
#   u'dependencies': [{u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'Crypto',
#                      u'path': u'/usr/lib/python2.7/dist-packages/Crypto',
#                      u'source': u'attribute',
#                      u'version': u'2.6'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'IPython',
#                      u'path': u'/home/wd15/git/ipython/IPython',
#                      u'source': u'/home/wd15/git/ipython',
#                      u'version': u'b31eb2f2d95146bfc0873670c649378872492dc7'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'PIL',
#                      u'path': u'/usr/lib/python2.7/dist-packages/PIL',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'PyQt4',
#                      u'path': u'/usr/lib/python2.7/dist-packages/PyQt4',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'PySide',
#                      u'path': u'/usr/lib/python2.7/dist-packages/PySide',
#                      u'source': u'attribute',
#                      u'version': u'1.1.2'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'PyTrilinos',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/PyTrilinos',
#                      u'source': u'attribute',
#                      u'version': u'4.8d'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'_markerlib',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/distribute-0.6.34-py2.7.egg/_markerlib',
#                      u'source': u'egg-info',
#                      u'version': u'0.6.34'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'dateutil',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/dateutil',
#                      u'source': u'attribute',
#                      u'version': u'2.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'distutils',
#                      u'path': u'/home/wd15/.virtualenvs/default/lib/python2.7/distutils',
#                      u'source': u'attribute',
#                      u'version': u'2.7.5'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'docutils',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/docutils',
#                      u'source': u'attribute',
#                      u'version': u'0.11'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'encodings',
#                      u'path': u'/home/wd15/.virtualenvs/default/lib/python2.7/encodings',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'diff --git a/examples/cahnHilliard/mesh2D.py b/examples/cahnHilliard/mesh2D.py\nindex 73e98a6..35765ce 100755\n--- a/examples/cahnHilliard/mesh2D.py\n+++ b/examples/cahnHilliard/mesh2D.py\n@@ -67,7 +67,7 @@ We can simulate this process in :term:`FiPy` with a simple script:\n much is augmented for :term:`FiPy`\\\'s needs.)\n \n >>> if __name__ == "__main__":\n-...     nx = ny = 1000\n+...     nx = ny = 100\n ... else:\n ...     nx = ny = 20\n >>> mesh = Grid2D(nx=nx, ny=ny, dx=0.25, dy=0.25)',
#                      u'module': u'python',
#                      u'name': u'fipy',
#                      u'path': u'/home/wd15/git/fipy/fipy',
#                      u'source': u'/home/wd15/git/fipy',
#                      u'version': u'c668e0f16ba4477a354c3f298b56e0cac620404f'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'gi',
#                      u'path': u'/usr/lib/python2.7/dist-packages/gi',
#                      u'source': u'attribute',
#                      u'version': u'3.10.0'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'glib',
#                      u'path': u'/usr/lib/python2.7/dist-packages/glib',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'gobject',
#                      u'path': u'/usr/lib/python2.7/dist-packages/gobject',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'gtk',
#                      u'path': u'/usr/lib/python2.7/dist-packages/gtk-2.0/gtk',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'matplotlib',
#                      u'path': u'/usr/lib/pymodules/python2.7/matplotlib',
#                      u'source': u'attribute',
#                      u'version': u'1.2.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'mayavi',
#                      u'path': u'/usr/lib/python2.7/dist-packages/mayavi',
#                      u'source': u'attribute',
#                      u'version': u'4.1.0'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'mpi4py',
#                      u'path': u'/usr/lib/python2.7/dist-packages/mpi4py',
#                      u'source': u'attribute',
#                      u'version': u'1.3'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'mpl_toolkits',
#                      u'path': u'/usr/lib/pymodules/python2.7/mpl_toolkits',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'nose',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/nose',
#                      u'source': u'attribute',
#                      u'version': u'1.3.0'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'numpy',
#                      u'path': u'/usr/lib/python2.7/dist-packages/numpy',
#                      u'source': u'attribute',
#                      u'version': u'1.7.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'paramiko',
#                      u'path': u'/usr/lib/python2.7/dist-packages/paramiko',
#                      u'source': u'attribute',
#                      u'version': u'1.10.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'pylsmlib',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/pylsmlib-0.1-py2.7-linux-x86_64.egg/pylsmlib',
#                      u'source': u'attribute',
#                      u'version': u'0.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'pysparse',
#                      u'path': u'/home/wd15/git/pysparse/pysparse',
#                      u'source': u'/home/wd15/git/pysparse',
#                      u'version': u'1751931aa5c06429245c3aca3a3ba6d7622ea8b5'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'pytz',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/pytz',
#                      u'source': u'attribute',
#                      u'version': u'2013b'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'scipy',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/scipy',
#                      u'source': u'attribute',
#                      u'version': u'0.13.0'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'setuptools',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/distribute-0.6.34-py2.7.egg/setuptools',
#                      u'source': u'attribute',
#                      u'version': u'0.6'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'skfmm',
#                      u'path': u'/home/wd15/git/scikit-fmm/skfmm',
#                      u'source': u'/home/wd15/git/scikit-fmm',
#                      u'version': u'78a243dd9d8cf014e86bb859523226fa8ed65f10'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'tornado',
#                      u'path': u'/home/wd15/.virtualenvs/default/local/lib/python2.7/site-packages/tornado',
#                      u'source': u'attribute',
#                      u'version': u'3.1.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'traits',
#                      u'path': u'/usr/lib/python2.7/dist-packages/traits',
#                      u'source': u'attribute',
#                      u'version': u'4.1.0'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'tvtk',
#                      u'path': u'/usr/lib/python2.7/dist-packages/tvtk',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'vtk',
#                      u'path': u'/usr/lib/pymodules/python2.7/vtk',
#                      u'source': None,
#                      u'version': u'unknown'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'wx',
#                      u'path': u'/usr/lib/python2.7/dist-packages/wx-2.8-gtk2-unicode/wx',
#                      u'source': u'attribute',
#                      u'version': u'2.8.12.1'},
#                     {u'diff': u'',
#                      u'module': u'python',
#                      u'name': u'zmq',
#                      u'path': u'/usr/lib/python2.7/dist-packages/zmq',
#                      u'source': u'attribute',
#                      u'version': u'13.1.0'}],
#   u'diff': u'',
#   u'duration': 0.3357048034667969,
#   u'executable': {u'name': u'Python',
#                   u'options': u'',
#                   u'path': u'/home/wd15/.virtualenvs/default/bin/python',
#                   u'version': u'2.7.4'},
#   u'input_data': [],
#   u'input_datastore': {u'parameters': {u'root': u'/'},
#                        u'type': u'FileSystemDataStore'},
#   u'label': u'4880ebbcc856',
#   u'launch_mode': {u'parameters': {u'options': None,
#                                    u'working_directory': u'/home/wd15/git/sumatrademo'},
#                    u'type': u'SerialLaunchMode'},
#   u'main_file': u'scripy.py',
#   u'outcome': u'',
#   u'output_data': [],
#   u'parameters': {u'content': u'{}', u'type': u'dict'},
#   u'platforms': [{u'architecture_bits': u'64bit',
#                   u'architecture_linkage': u'ELF',
#                   u'ip_addr': u'127.0.0.1',
#                   u'machine': u'x86_64',
#                   u'network_name': u'loki',
#                   u'processor': u'x86_64',
#                   u'release': u'3.11.0-12-generic',
#                   u'system_name': u'Linux',
#                   u'version': u'#19-Ubuntu SMP Wed Oct 9 16:20:46 UTC 2013'}],
#   u'reason': u'',
#   u'repeats': None,
#   u'repository': {u'type': u'GitRepository',
#                   u'upstream': None,
#                   u'url': u'/home/wd15/git/sumatrademo'},
#   u'script_arguments': u'',
#   u'stdout_stderr': u'No output.',
#   u'tags': [],
#   u'timestamp': u'2013-11-08 10:39:45',
#   u'user': u'Daniel Wheeler <daniel.wheeler2@gmail.com>',
#   u'version': u'90e58171d0489785d251cd7f1f0ae2a1e496438d'}]
